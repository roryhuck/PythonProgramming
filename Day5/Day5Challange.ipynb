# %% [markdown]
# ## Challenge Problem Day 5
# ## Intro to python
# ### By: Rory Huck

# %% [markdown]
# the first line defines a list of 7 colors. then creates empty sets of dark, light, and regular colors. the for statement then saus of the colors has light it in add it to the light color list, same for dark and regular colors. then it asks for the new seperated lists of colors to be printed.

# %%
colors = ['blue', 'green', 'purple', 'pink']
fav = ['blue','pink']

for c in colors:
    if c in fav:
        print(f"{c} is the best color!")
    else:
        print(f"{c} is meh!")
# Out:
# blue is the best color!
# green is meh!
# purple is meh!
# pink is the best color!
