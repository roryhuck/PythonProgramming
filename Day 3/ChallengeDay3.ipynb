# %% [markdown]
# ## Challenge Problem Day 3
# ## Intro to python
# ### By: Rory Huck

# %%
animals = ['Dog','Cat','Horse','Fish','Zebra']
print(animals)
# Out:
# ['Dog', 'Cat', 'Horse', 'Fish', 'Zebra']

# %%
removed_animal = animals.pop()

# %%
added = animals.append('Lion')

# %%
print(
    f"We started with a list that was {len(animals)}. "
    f"We removed {removed_animal}. "
    f"We added Lion. "
    f"The first animal on the list is {animals[0]}."
)
# Out:
# We started with a list that was 5. We removed Zebra. We added Lion. The first animal on the list is Dog.
