# %% [markdown]
# ## Python Programming
# ### Challenge Problem day 2
# #### By: Rory Huck

# %%
# defining my variables
v_1 = 'Rory'
v_2 = 5
v_3 = 3.5

# %%
my_statement = (
    f"This is my string: [{v_1}]."
    f"This is my integer: [{v_2}]. "
    f"This is my float: [{v_3}]. " 
)
print(my_statement)
# Out:
# This is my string: [Rory].This is my integer: [5]. This is my float: [3.5].
