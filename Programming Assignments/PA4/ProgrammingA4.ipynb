# %% [markdown]
# ## Python Programming
# ### Programming Assignemnt 4
# #### By: Rory Huck

# %%
import random

my_animals = {
    'dog': ['Barks', 'Normal pet'],
    'cat': ['Meows', 'Common pet'],
    'horse': ['Neighs', 'Lives in a barn'],
    'bird': ['Chirps', 'Has a beak']
}

print('Animal Guessing Game')
print('Rules:')
print('- You will get clues about an animal')
print('- You have 3 guesses')
print("- Type 'quit' to stop\n")

play = input('Want to play? (yes/no): ')

if play == 'yes':

    secret_animal = random.choice(list(my_animals.keys()))
    clues = my_animals[secret_animal]

    guesses = 0
    max_guesses = 2
    guessed_animal = []

    while guesses < max_guesses:

        print('\nClue:', clues[guesses.len(clues)])

        guess = input('Guess (or quit): ')

        if guess == 'quit':
            print('You quit the game.')
            break

        if guess in guessed_animal:
            print('You already guessed that!')
            continue

        guessed_animal.append(guess)
        guesses += 1

        if guess.lower() == secret_animal:
            print('Correct! You win!')
            break
        else:
            print('Wrong!')

    if guess != secret_animal:
        print('Game over! The animal was:', secret_animal)

else:
    print('Maybe next time.')
# Out:
# Animal Guessing Game
# Rules:
# - You will get clues about an animal
# - You have 3 guesses
# - Type 'quit' to stop
# Want to play? (yes/no):  yes
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 29
#      25 guessed_animal = []
#      27 while guesses < max_guesses:
# ---> 29     print('\nClue:', clues[guesses.len(clues)])
#      31     guess = input('Guess (or quit): ')
#      33     if guess == 'quit':
#
# AttributeError: 'int' object has no attribute 'len'
