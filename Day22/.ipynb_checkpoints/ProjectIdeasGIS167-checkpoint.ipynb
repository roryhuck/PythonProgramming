# %% [markdown]
# ## Project Ideas:
#
# ### Mini Video Game: (Level 2 or 3 depending on the complexity of the game and user interaction.)
# You could create a game either just using the user input of Google Colab (or the terminal). This should be more complicated than the games that we programmed as part of our practice assignments. Here is an example of a more complicated game, along with a fancy logo screen (Level 2-3)
#
# https://www.geeksforgeeks.org/higher-lower-game-with-python/
#
# You could follow the tutorial and then make up a game that is your own. If you want a challenge you could learn how to program a graphical user interface (GUI). We did not cover this in class and you would likely have to do this in Jupyter Notebooks or PyCharm on your own computer. Here is an example of a hangman game with a GUI: (Level 3+)
#
# https://realpython.com/hangman-python-pysimplegui/
#
# You could follow the tutorial and the find ways to make the game your own. Maybe try tic-tac-toe, or mini-wordle.
#
#
# ### Web Scraping and a Desktop Notification App: (Level 3)
#
# Here is an example of a weather app build using Python:
#
# https://www.geeksforgeeks.org/get-live-weather-desktop-notifications-using-python/
#
#
# You would have to program this in PyCharm or Jupyter Notebooks on your own computer to make it work. To make it your own you could think about websites you might want to scrape and get info from. Maybe an app that gives you updates about your favorite sports team.
#
# You could also just create some webscraping code and leave out the desktop notification parts. The user would interact with your code directly on Colab (Level 2)
#
#
# ### Pattern Printer (Level 1, 2, or 3 depending on the complexity of the pattern and the amount of user interaction)
#
# Making a program that produces different designs using loops and conditional statements is the goal of the Python project known as the Pattern Printer. Typically, a computer program will ask the user to specify the pattern's size or shape, producing the relevant design using symbols or letters. Python uses loop constructs like for and while loops to cycle over the rows and columns in this project. The pattern architecture and symbol placement are decided by the program using logic and conditional expressions. Shapes like squares, triangles, diamonds, and personalized patterns are examples of patterns. Can you combine ideas from the tutorial below to make really cool print outs?
#
# https://www.shiksha.com/online-courses/articles/pattern-programs-in-python/
#
# ### Build a Quiz Game (Level 1, 2, or 3 depending on the complexity of the quiz and the amount of user interaction)
#
# The Python Quiz project entails developing a program that asks the user an array of questions and assesses their responses. Usually, the program reads the user's questions and the accompanying choices from a file or database, shows them, accepts their answers, and then computes the user's final score. Python uses ideas like file management, data structures, loops, and conditional expressions to carry out this project. The software may include timers, suggestions, multiple-choice questions, and score tracking. Additionally, it can offer commentary on the right and wrong responses and, at the conclusion, show a summary of the user's performance.
#
#
# ### Budget/Health/etc tracker code: (Level 1, 2, or 3 depending on the user interaction and they types of outputs/analysis you produce)
#
# Python code that helps you manage your budget - you enter your expenses, a date, and a category. Saves the data to a file. Then you can specify a month and it prints out a graph (bar graph?) of your expenses, tracks expenses over time, etc
#
# You could also write other type of trackers - health trackers to track things you care about with your health.
#
# ### Data Analysis: (Level 1, 2 , or 3 depending on the complexity of the analysis, the discussion of the results, and the number/complexity of the graphical representations.)
#
# Get some data that is interesting to you and do an analysis of that data. Ask lots of interesting questions, make some useful graphical illustrations of the information, combine different data sets to form more interesting analysis.
#
# You could use GeoPandas to interacat with spatial data or regular Pandas to look at non-spatial data.
#
# ### Chapter 12-14 in the book
# Build an alien invasion game (Level 3+)
#
# ### Chapter 18-20 in the book
# Learning Django to build a learning app, allowing users to build accounts, and then releasing your app on a servier (Very Advanced = Level 3+++)
