# %% [markdown]
# ## Intro to Python Programming
# - Prof Joanna Bieri
# - Office: Duke 209
#
# ### Day 11 - Reading and Writing data from Files
#
# In order to really levrage the abilities of Python we need to know how to read in data, interact with it, and then write that data to files so we can access it later. Today we will go over the basics of reading and writing data of different types, but look out over the rest of the semester and we introduce more advanced input/output ideas.

# %% [markdown]
# ### Text files

# %%
# Writing data to a file - the standard way to a file the directory
# with open('my_birthday.txt', mode='w') as bday:
#     bday.write('2-7-79')
    
# Or write whole strings to a given directory path
from pathlib import Path
path = Path('my_birthday.txt')
path.write_text('2-7-79')
print('Check the file my_birthday.txt it should contain the data!')
# Out:
# Check the file my_birthday.txt it should contain the data!

# %%
# Reading data from a file - standard way from a file in the directory
with open('my_birthday.txt', mode='r') as bday:
    for day in bday:
        print(day)  
        
# Or you can read the whole thing from a given directory path
# from pathlib import Path
# path = Path('my_birthday.txt')
# day = path.read_text()
# print(day)
# Out:
# 2-7-79

# %%
# Writing multiple lines
people = ['Mom','Dad','Kristin','Bongo']
birthdays = ['12-10','3-2','11-6','11-25']

with open('family_birthdays.txt', mode='w') as bday:
    for i in range(len(people)):
        info = f'{people[i]}:{birthdays[i]}\n'
        bday.write(info)

# %%
sample_string = 'Joanna:2-7-1979\n'
sample_string.strip('\n').split(':')
# Out:
# ['Joanna', '2-7-1979']

# %%
# Reading multiple lines and saving the data
people_new = []
birthdays_new = []

with open('family_birthdays.txt', mode='r') as bday:
    for item in bday:
        # print(item)
        # print(item.strip('\n').split(':'))
        info = item.strip('\n').split(':')
        people_new.append(info[0])
        birthdays_new.append(info[1])
print(people_new)
print(birthdays_new)
# Out:
# ['Mom', 'Dad', 'Kristin', 'Bongo']
# ['12-10', '3-2', '11-6', '11-25']

# %%
# Appending to the end of a file
more_people = ['Ross','Bella']
more_birthdays = ['9-25','5-20']

# mode = 'a' lets you append to the bottom of the file!
with open('family_birthdays.txt', mode='a') as bday:
    for i in range(len(more_people)):
        info = f'{more_people[i]}:{more_birthdays[i]}\n'
        bday.write(info)
        
# Code coppied from above to read the file again        
people_new = []
birthdays_new = []
with open('family_birthdays.txt', mode='r') as bday:
    for item in bday:
        # print(item)
        # print(item.strip('\n').split(':'))
        info = item.strip('\n').split(':')
        people_new.append(info[0])
        birthdays_new.append(info[1])
print(people_new)
print(birthdays_new)
# Out:
# ['Mom', 'Dad', 'Kristin', 'Bongo', 'Ross', 'Bella']
# ['12-10', '3-2', '11-6', '11-25', '9-25', '5-20']

# %%
# Is my birthday in the first million digits of pi?
# one-million.txt
# 1 Million Digits of Pi
# collected by Eve Andersson
# http://www.eveandersson.com/pi/digits/1000000

# Read in the birthday and remove the dashes
with open('my_birthday.txt', mode='r') as bday:
    for day in bday:
        myday = day.replace('-','')
        

# Read in the digits of pi from the file
pi_string = ''
with open('one-million.txt', mode='r') as digits:
    for d in digits:
        pi_string += d
    
# Check to see if your birthday is in there
if myday in pi_string:
    place = pi_string.find(myday)
    print(f'Found your birthday! {myday} is at location {place} in pi.')
else:
    print('Birthday not found!')
# Out:
# Found your birthday! 2779 is at location 15310 in pi.

# %% [markdown]
# ### Practice Problem 1
#
# Copy and paste your code from programming assignment 2 - that creates user emails to a list of people with a corresponding list of products. Then alter that code, so that instead of printing that information to the screen, it saves that data in a file called user_emails.txt.
#
# Check that your code is working by opening the file to see what is inside!

# %%
# Your code here

# %% [markdown]
# ### Practice Problem 2
#
# Read in the file mystery.txt, print out each line. What is it?

# %%
# Your code here

# %% [markdown]
# ### Image Files
#
# Digital images are just files that contain numbers as data. That data is then interpreted by the computer to become the pictures that we are use to seeing. But you can interact with image data just like we have been interacting with lists.

# %%
import matplotlib.pyplot as plt

# Read the image from the file
my_map = plt.imread('map.png')
# Choose the size of the plot
plt.figure(figsize=(16,8))
# Plot the Image
plt.imshow(my_map)
# Show the image nicely on the screen
plt.show()

# %%
# What is the data here?
print(my_map.shape)
# This is FOUR arrays (or multi columned lists) of data each 1275X1749 pixels rectangle.
# The four layers are Red, Green, Blue, and Transparancy
# my_map
# Out:
# (1275, 1749, 4)

# %% [markdown]
# Computers read in image data as colors and transparencies. Then they layer that data on top and interpret it into a image. Once you have a basic image, you can always layer more information over the top!
#
# If you are interested it GIS or spatial studies. This is the basis for many of the maps that are curated with the ESRI software. Get a detailed map, along with data about the locations on that map. Then layer the information. Obviously they then build in lots of functions and operations!

# %%
# Adding data to an image:
# We need data for the latitude and longitude of the edges of the plot
BBox = ((-117.17166, -117.15589,      
         34.05830, 34.06782))
# We need latitude and longitude data for each of our data points
Duke = (-117.1664,34.0617)

# Choose the image size
plt.figure(figsize=(16,8))
# Telll python the longitude and latitude of each corner of the map
plt.xlim(BBox[0],BBox[1])
plt.ylim(BBox[2],BBox[3])
# Create a scatter plot of points we are interested in
plt.scatter(Duke[0], Duke[1], alpha= 0.9, c='r', s=200)
# Add the plot under the points
plt.imshow(my_map, extent = BBox, aspect= 'equal')
plt.show()

# %% [markdown]
# ### More fun with Images
#
# There are lots of libraries for playing with images in python! We are going to learn about skimage here. We will import some specific tools and then use them.
#
# Inspired by: https://towardsdatascience.com/introduction-to-image-processing-with-python-representation-of-images-for-beginners-b95725b523ca

# %%
# Number and Plotting tools
import numpy as np
import matplotlib.pyplot as plt

# Image tools
from skimage import img_as_uint
from skimage.io import imshow, imread
from skimage.color import rgb2hsv
from skimage.color import rgb2gray

# %%
# Here is a very simple image (checkerboard)
checkers = np.array([[255, 0, 255], 
                    [0, 255, 0],
                    [255, 0, 255]])
imshow(checkers, cmap = 'gray')
# Out:
# /usr/local/lib/python3.10/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:149: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
# Here is a very simple image (checkerboard)
# But now python will think of it in colors!
colors = np.array([[[255, 0, 0], 
                         [0, 255, 0],
                         [0, 0, 255]]])
color_names = ['red','green','blue']

imshow(colors)

for i,c in enumerate(color_names):
    print(f'The matrix {colors[0][i]} gives the color {c}')
# Out:
# The matrix [255   0   0] gives the color red
# The matrix [  0 255   0] gives the color green
# The matrix [  0   0 255] gives the color blue

# %%
# The same thing happens for real images
study_cat = imread('studycat.jpg')
imshow(study_cat)
print(f'The shape of this data is {study_cat.shape}')
# Out:
# The shape of this data is (499, 487, 3)

# %%
# Slice the image - just like slices of a list we can slice these arrays!
sliced_cat = study_cat[:,150:250]
imshow(sliced_cat)

# %% [markdown]
# ### Practice Problem 3
#
# See if you can slice the image horizontally AND vertically so you are zooming in on just the cat's face. You might have to play around for a bit to get the right numbers!

# %%
# Your code here

# %% [markdown]
# Because the image is a layer of red, green, and blue, we can look at each layer separately!

# %%
# The red layer is the first one study_cat[:,:,0]
imshow(study_cat[:,:,0], cmap='Reds')

# %%
# The green layer is the second one study_cat[:,:,0]
imshow(study_cat[:,:,1], cmap='Greens')

# %% [markdown]
# ### Practice Problem 4
#
# Write code that showns just the blue layer.

# %%
# Your code here

# %%
# We can play around with other aspects of the image
gray_cat = rgb2gray(study_cat)
imshow(gray_cat)

# %%
hsv_cat = rgb2hsv(study_cat)
imshow(hsv_cat)

# %%
# You could even go in and change specific pixels!
sp = study_cat.shape
for i in range(sp[0]):
    for j in range(sp[1]):
        if i == j:
            study_cat[i,j,:] = 255
imshow(study_cat)

# %% [markdown]
# ### Importing Data Files
#
# The two most common formats for data files is
#
# - .csv - comma separated values
# - .json - java script object notation
#
# I tend to use .csv for most projects, but .json is really useful too!

# %%
import pandas as pd
# pd.read_
# Out:
# /home/bellajagu/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/bellajagu/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %% [markdown]
# Pandas can read lots of different data types!
#
# - pd.read_clipboard
# - pd.read_excel
# - pd.read_json
# - pd.read_html
#
# and many more!
#
# They all have the same basic format.

# %% [markdown]
# ### Read Data from a .csv

# %%
file_name = 'top_50_2023.csv'
df = pd.read_csv(file_name)
df
# Out:
#            artist_name                                         track_name  \
# 0          Miley Cyrus                                            Flowers
# 1                  SZA                                          Kill Bill
# 2         Harry Styles                                          As It Was
# 3            Jung Kook                Seven (feat. Latto) (Explicit Ver.)
# 4       Eslabon Armado                                    Ella Baila Sola
# 5         Taylor Swift                                       Cruel Summer
# 6         Metro Boomin             Creepin' (with The Weeknd & 21 Savage)
# 7                 Rema                      Calm Down (with Selena Gomez)
# 8             Bizarrap              Shakira: Bzrp Music Sessions, Vol. 53
# 9         Taylor Swift                                          Anti-Hero
# 10      Arctic Monkeys                                   I Wanna Be Yours
# 11             KAROL G                                                TQG
# 12           Yng Lvcas                                    La Bebe - Remix
# 13        David Guetta                                    I'm Good (Blue)
# 14          The Weeknd                                        Die For You
# 15      Grupo Frontera                                          un x100to
# 16           Sam Smith                          Unholy (feat. Kim Petras)
# 17       Manuel Turizo                                         La Bachata
# 18      PinkPantheress                                 Boy's a liar Pt. 2
# 19       David Kushner                                           Daylight
# 20           Tom Odell                                       Another Love
# 21          The Weeknd                                            Starboy
# 22              Yandel                                         Yandel 150
# 23         FIFTY FIFTY                                  Cupid - Twin Ver.
# 24          The Weeknd           Die For You (with Ariana Grande) - Remix
# 25         OneRepublic                                    I Ain't Worried
# 26                d4vd                                       Here With Me
# 27       Morgan Wallen                                         Last Night
# 28                JVKE                                        golden hour
# 29     Stephen Sanchez  Until I Found You (with Em Beihold) - Em Beiho...
# 30         Myke Towers                                               LALA
# 31            Bizarrap              Quevedo: Bzrp Music Sessions, Vol. 52
# 32               Ozuna                                            Hey Mor
# 33                Feid                                         CLASSY 101
# 34            Doja Cat                                 Paint The Town Red
# 35   The Neighbourhood                                    Sweater Weather
# 36                 SZA                                             Snooze
# 37        Taylor Swift                                        Blank Space
# 38          The Weeknd                                    Blinding Lights
# 39           Bad Bunny                                     WHERE SHE GOES
# 40               Jimin                                         Like Crazy
# 41              Eminem                                        Mockingbird
# 42                RAYE                                          Escapism.
# 43      Olivia Rodrigo                                            vampire
# 44          Peso Pluma                                                PRC
# 45  Tyler, The Creator                   See You Again (feat. Kali Uchis)
# 46           Bad Bunny                                    Me Porto Bonito
# 47            NewJeans                                                OMG
# 48       Natanael Cano                                                AMG
# 49                d4vd                                  Romantic Homicide
#
#     is_explicit album_release_date  \
# 0         False         2023-08-18
# 1         False         2022-12-08
# 2         False         2022-05-20
# 3          True         2023-11-03
# 4         False         2023-04-28
# 5         False         2019-08-23
# 6          True         2022-12-02
# 7         False         2023-04-27
# 8         False         2023-01-11
# 9         False         2022-10-21
# 10        False         2013-09-09
# 11         True         2023-02-24
# 12         True         2023-03-17
# 13         True         2022-08-26
# 14        False         2016-11-24
# 15        False         2023-08-25
# 16        False         2023-01-27
# 17        False         2023-03-17
# 18         True         2023-11-10
# 19        False         2023-04-14
# 20         True         2013-06-24
# 21         True         2016-11-25
# 22         True         2023-01-13
# 23        False         2023-09-22
# 24        False         2023-03-14
# 25        False         2022-05-13
# 26        False         2023-05-26
# 27         True         2023-03-03
# 28        False         2022-09-23
# 29        False         2022-04-22
# 30         True         2023-03-23
# 31        False         2022-07-06
# 32        False         2022-10-07
# 33         True         2023-03-31
# 34         True         2023-09-20
# 35        False         2013-04-19
# 36         True         2022-12-09
# 37        False         2014-10-27
# 38        False         2020-03-20
# 39         True         2023-10-13
# 40        False         2023-03-24
# 41         True         2004-11-12
# 42         True         2023-02-03
# 43         True         2023-09-08
# 44         True         2023-06-29
# 45         True         2017-07-21
# 46         True         2022-05-06
# 47        False         2023-01-02
# 48         True         2023-06-30
# 49        False         2022-07-20
#
#                                                genres  danceability  valence  \
# 0                                             ['pop']         0.706    0.632
# 1                               ['pop', 'r&b', 'rap']         0.644    0.418
# 2                                             ['pop']         0.520    0.662
# 3                                           ['k-pop']         0.790    0.872
# 4   ['corrido', 'corridos tumbados', 'sad sierreno...         0.668    0.834
# 5                                             ['pop']         0.552    0.564
# 6                                             ['rap']         0.715    0.172
# 7                       ['afrobeats', 'nigerian pop']         0.799    0.811
# 8   ['argentine hip hop', 'pop venezolano', 'trap ...         0.778    0.498
# 9                                             ['pop']         0.637    0.533
# 10  ['garage rock', 'modern rock', 'permanent wave...         0.464    0.479
# 11  ['reggaeton', 'reggaeton colombiano', 'trap la...         0.720    0.607
# 12                   ['reggaeton', 'urbano mexicano']         0.812    0.559
# 13  ['big room', 'dance pop', 'edm', 'pop', 'pop d...         0.561    0.304
# 14  ['canadian contemporary r&b', 'canadian pop', ...         0.586    0.508
# 15                            ['musica chihuahuense']         0.571    0.542
# 16                                  ['pop', 'uk pop']         0.712    0.206
# 17  ['colombian pop', 'latin pop', 'reggaeton', 'r...         0.835    0.850
# 18                                    ['bedroom pop']         0.696    0.857
# 19  ['gen z singer-songwriter', 'singer-songwriter...         0.508    0.324
# 20                                      ['chill pop']         0.445    0.131
# 21  ['canadian contemporary r&b', 'canadian pop', ...         0.679    0.486
# 22  ['latin hip hop', 'reggaeton', 'trap latino', ...         0.783    0.580
# 23                               ['k-pop girl group']         0.783    0.726
# 24  ['canadian contemporary r&b', 'canadian pop', ...         0.575    0.506
# 25                              ['piano rock', 'pop']         0.704    0.825
# 26                                    ['bedroom pop']         0.571    0.299
# 27                           ['contemporary country']         0.492    0.478
# 28  ['modern indie pop', 'pov: indie', 'singer-son...         0.515    0.153
# 29                        ['gen z singer-songwriter']         0.551    0.342
# 30      ['reggaeton', 'trap latino', 'urbano latino']         0.708    0.607
# 31  ['argentine hip hop', 'pop venezolano', 'trap ...         0.621    0.550
# 32  ['puerto rican pop', 'reggaeton', 'trap latino...         0.901    0.399
# 33  ['colombian pop', 'pop reggaeton', 'reggaeton'...         0.859    0.672
# 34                               ['dance pop', 'pop']         0.864    0.726
# 35  ['modern alternative rock', 'modern rock', 'pop']         0.612    0.398
# 36                              ['pop', 'r&b', 'rap']         0.559    0.392
# 37                                            ['pop']         0.753    0.583
# 38  ['canadian contemporary r&b', 'canadian pop', ...         0.514    0.334
# 39      ['reggaeton', 'trap latino', 'urbano latino']         0.651    0.223
# 40                                          ['k-pop']         0.629    0.362
# 41              ['detroit hip hop', 'hip hop', 'rap']         0.637    0.254
# 42                  ['uk contemporary r&b', 'uk pop']         0.538    0.250
# 43                                            ['pop']         0.511    0.350
# 44              ['corridos tumbados', 'sad sierreno']         0.784    0.893
# 45                                 ['hip hop', 'rap']         0.558    0.620
# 46      ['reggaeton', 'trap latino', 'urbano latino']         0.911    0.425
# 47                      ['k-pop', 'k-pop girl group']         0.804    0.739
# 48  ['corrido', 'corridos tumbados', 'musica mexic...         0.772    0.786
# 49                                    ['bedroom pop']         0.571    0.216
#
#     energy  loudness  acousticness  instrumentalness  liveness  speechiness  \
# 0    0.691    -4.775       0.05840          0.000070    0.0232       0.0633
# 1    0.735    -5.747       0.05210          0.144000    0.1610       0.0391
# 2    0.731    -5.338       0.34200          0.001010    0.3110       0.0557
# 3    0.831    -4.185       0.31200          0.000000    0.0797       0.0440
# 4    0.758    -5.176       0.48300          0.000019    0.0837       0.0332
# 5    0.702    -5.707       0.11700          0.000021    0.1050       0.1570
# 6    0.620    -6.005       0.41700          0.000000    0.0822       0.0484
# 7    0.802    -5.196       0.42900          0.001280    0.1710       0.0371
# 8    0.632    -5.600       0.27400          0.000000    0.0915       0.0493
# 7    11  107.008     1       239318               4          90
# 8     2  122.104     0       218289               4          85
# 9     4   97.008     1       200690               4          92
# 10    0   67.528     0       183956               4          96
# 11    4  179.974     0       199440               4          88
# 12    2  169.922     0       234353               4          89
# 13    7  128.040     0       175238               4          92
# 14    1  133.629     0       260253               4          85
# 15    9   83.827     1       194563               4          85
# 16    2  131.199     1       156943               4          84
# 17    7  124.980     0       162638               4          85
# 18    5  132.962     1       131013               4          84
# 19    2  130.090     0       212954               4          94
# 20    4  122.769     0       244360               4          72
# 21    7  186.003     1       230453               4          95
# 22    6  167.968     0       216148               4          83
# 23   11  120.018     0       174253               4          75
# 24    1   67.033     0       232857               4          85
# 25    0  139.994     1       148486               4          92
# 26    4  132.025     1       242485               4          90
# 27    6  203.759     1       163855               4          84
# 28    4   94.467     1       209260               3          83
# 29   10  101.190     1       176440               3          90
# 30    1   91.986     1       197920               4          93
# 31    2  128.033     1       198938               4          88
# 32    1   98.002     0       196600               4          87
# 33   11  100.065     1       195987               4          87
# 34    2   99.974     0       230480               4          93
# 35   10  124.053     1       240400               4          93
# 36    5  143.008     1       201800               4          93
# 37    5   96.006     1       231827               4          78
# 38    1  171.005     1       200040               4          93
# 39    9  143.992     0       231704               4          84
# 40    7  120.001     1       212241               4          93
# 41    0   84.039     1       250760               4          91
# 42    2   96.107     1       272373               4          76
# 43    5  138.005     1       219724               4          95
# 44    7  138.078     0       184066               3          82
# 45    6   78.558     1       180387               4          92
# 46    1   92.005     0       178567               4          89
# 47    9  126.956     0       212253               4          87
# 48   11  136.175     0       174943               3          81
# 49    6  132.052     1       132631               4          91

# %%
# See what columns are in the table
df.keys()
# Out:
# Index(['artist_name', 'track_name', 'is_explicit', 'album_release_date',
#        'genres', 'danceability', 'valence', 'energy', 'loudness',
#        'acousticness', 'instrumentalness', 'liveness', 'speechiness', 'key',
#        'tempo', 'mode', 'duration_ms', 'time_signature', 'popularity'],
#       dtype='object')

# %%
# Get the data in one column and save it as a list
artists = list(df['artist_name'])
tracks = list(df['track_name'])

# %%
# What does this code do?
e_songs = df['is_explicit']

for i in range(len(e_songs)):
    if e_songs[i] == True:
        with open('song_list.txt', mode='a') as elist:
            message = f'The song {tracks[i]} by {artists[i]} has explicit lyrics.\n'
            elist.write(message)

# %%
# Your answer here:

# %% [markdown]
# ### Read tables from a webpage
#
# Assuming there are tables on the webpage!

# %%
# NOTE: Wikipedia changed permissions
# We are reading in the data with a few more commands

import requests
from io import StringIO

# Here is the website
url = "https://en.wikipedia.org/wiki/California"

# Send header information - no need to change
headers = {"User-Agent": "Mozilla/5.0"}
# Get the html code
html = requests.get(url, headers=headers).text

CA_data = pd.read_html(StringIO(html))

# %%
for data in CA_data:
    display(data)
# Out:
#                                            California  \
# 0                                               State
# 1                                            FlagSeal
# 2                       Nickname: The Golden State[4]
# 3                                  Motto: "Eureka"[5]
# 4                    Anthem: "I Love You, California"
# 5     Location of California within the United States
# 6                                             Country
# 7                                    Before statehood
# 8                               Admitted to the Union
# 9                                             Capital
# 10                                       Largest city
# 11                       Largest county or equivalent
# 12                      Largest metro and urban areas
# 13                                         Government
# 14                                         • Governor
# 15                              • Lieutenant Governor
# 16                                        Legislature
# 17                                      • Upper house
# 18                                      • Lower house
# 19                                          Judiciary
# 20                                      U.S. senators
# 21                              U.S. House delegation
# 22                                               Area
# 23                                            • Total
# 24                                             • Land
# 25                                            • Water
# 26                                             • Rank
# 27                                         Dimensions
# 28                                           • Length
# 29                                            • Width
# 30                                          Elevation
# 31  Highest elevation (Mount Whitney[6][7][note 1]...
# 32               Lowest elevation (Badwater Basin[8])
# 33                                  Population (2025)
# 34                                            • Total
# 35                                             • Rank
# 36                                          • Density
# 37                                             • Rank
# 38                          • Median household income
# 39                                      • Income rank
# 40                                         Demonym(s)
# 41                                           Language
# 42                                • Official language
# 43                                  • Spoken language
# 44                                          Time zone
# 45                                     • Summer (DST)
# 46                                  USPS abbreviation
# 47                                      ISO 3166 code
# 48                           Traditional abbreviation
# 49                                           Latitude
# 50                                          Longitude
# 51                                            Website
#
#                                          California.1
# 0                                               State
# 1                                            FlagSeal
# 2                       Nickname: The Golden State[4]
# 3                                  Motto: "Eureka"[5]
# 4                    Anthem: "I Love You, California"
# 5     Location of California within the United States
# 6                                       United States
# 7               Mexican Cession unorganized territory
# 8             September 9, 1850; 175 years ago (31st)
# 9                                          Sacramento
# 10                                        Los Angeles
# 11                                        Los Angeles
# 12                                Greater Los Angeles
# 13                                         Government
# 14                                   Gavin Newsom (D)
# 15                               Eleni Kounalakis (D)
# 16                                  State Legislature
# 17                                       State Senate
# 18                                     State Assembly
# 19                        Supreme Court of California
# 20                   Alex Padilla (D) Adam Schiff (D)
# 21        43 Democrats 8 Republicans 1 vacant  (list)
# 22                                               Area
# 23                        163,700 sq mi (423,970 km2)
# 24                        155,959 sq mi (403,932 km2)
# 25                      7,740 sq mi (20,047 km2) 4.7%
# 26                                                3rd
# 27                                         Dimensions
# 28                                  760 mi (1,220 km)
# 29                                    250 mi (400 km)
# 30                                   2,890 ft (880 m)
# 31                            14,504.6 ft (4,421.0 m)
# 32                                −278.9 ft (−85.0 m)
# 33                                  Population (2025)
# 34                                     39,355,309 [1]
# 35                                                1st
# 36                                 250/sq mi (97/km2)
# 37                                               11th
# 38                                  $95,500 (2023)[2]
# 39                                                5th
# 40  Californian Californio (archaic Spanish) Calif...
# 41                                           Language
# 42                                            English
# 43     English: 56.1% Spanish: 28.3% Others: 15.6%[3]
# 44                                    UTC−08:00 (PST)
# 45                                    UTC−07:00 (PDT)
# 46                                                 CA
# 47                                              US-CA
# 48                                Calif., Cal., Cali.
# 49                                  32°32′ N to 42° N
# 50                              114°8′ W to 124°26′ W
# 51                                             ca.gov
#                    List of state symbols  \
#                          Living insignia
# 0                              Amphibian
# 1                                   Bird
# 2                             Crustacean
# 3                                   Fish
# 4                                 Flower
# 5                                  Fruit
# 6                                  Grass
# 7                                 Insect
# 8                                 Mammal
# 9                               Mushroom
# 10                               Reptile
# 11                                  Tree
# 12                             Vegetable
# 13                    Inanimate insignia
# 14                                Colors
# 15                                 Dance
# 16                              Dinosaur
# 17                            Folk dance
# 18                                Fossil
# 19                              Gemstone
# 20                               Mineral
# 21                                  Rock
# 22                                  Ship
# 23                                  Soil
# 24                                 Sport
# 25                                Tartan
# 26                    State route marker
# 27                                   NaN
# 28                         State quarter
# 29                      Released in 2005
# 30  Lists of United States state symbols
#
#
#                                     Living insignia.1
# 0                          California red-legged frog
# 1                                    California quail
# 2                                      Dungeness crab
# 3          Fresh water: Golden troutMarine: Garibaldi
# 4                                    California poppy
# 5                                             Avocado
# 6                                  Purple needlegrass
# 7                        California dogface butterfly
# 8   Land: California grizzly bear (state animal)[5...
# 9                       California Golden Chanterelle
# 10                                    Desert tortoise
# 11                  Coast redwood & giant sequoia[10]
# 12                                          Artichoke
# 13                                 Inanimate insignia
# 14                                     Blue & Gold[9]
# 15                                   West Coast Swing
# 16                                    Augustynolophus
# 17                                       Square dance
# 18                                  Sabre-toothed cat
# 19                                          Benitoite
# 20                                        Native gold
# 21                                         Serpentine
# 22                                        Californian
# 23                                        San Joaquin
# 24                                            Surfing
# 25                            California state tartan
# 26                                 State route marker
# 27                                                NaN
# 28                                      State quarter
# 29                                   Released in 2005
# 30               Lists of United States state symbols
#           Location August (°F) August (°C) January (°F) January (°C)  \
# 0      Los Angeles       83/64       29/18        66/48         20/8
# 1   LAX/LA Beaches       75/64       23/18        65/49         18/9
# 2        San Diego       76/67       24/19        65/49         18/9
# 3         San Jose       82/58       27/14        58/42         14/5
# 4    San Francisco       67/54       20/12        56/46         14/8
# 5           Fresno       97/66       34/19        55/38         12/3
# 6       Sacramento       91/58       33/14        54/39         12/3
# 7          Oakland       73/58       23/14        58/44         14/7
# 8      Bakersfield       96/69       36/21        56/39         13/3
# 9        Riverside       94/60       35/18        67/39         19/4
# 10          Eureka       62/53       16/11        54/41         12/5
# 11    Death Valley      115/86       46/30        67/40         19/4
# 12   Mammoth Lakes       77/45        25/7        40/15        4/ −9
#
#    Annual precipitation (mm/in)
# 0                        377/15
# 1                        326/13
# 2                        262/10
# 3                        401/16
# 4                        538/21
# 5                        292/11
# 6                        469/18
# 7                        588/23
# 8                         165/7
# 9                        260/10
# 10                       960/38
# 11                         60/2
# 12                       583/23
#   Largest cities or towns in California Source:[170]                 \
#                                                 Rank           Name
# 0                                                  1    Los Angeles
# 1                                                  2      San Diego
# 2                                                  3       San Jose
# 3                                                  4  San Francisco
# 4                                                  5         Fresno
# 5                                                  6     Sacramento
# 6                                                  7     Long Beach
# 7                                                  8        Oakland
# 8                                                  9    Bakersfield
# 9                                                 10        Anaheim
#
#                                                                           \
#           County     Pop. Rank.1          Name.1        County.1  Pop..1
# 0    Los Angeles  3898747     11        Stockton     San Joaquin  320804
# 1      San Diego  1386932     12       Riverside       Riverside  314998
# 2    Santa Clara  1013240     13       Santa Ana          Orange  310227
# 3  San Francisco   873965     14          Irvine          Orange  307670
# 4         Fresno   542107     15     Chula Vista       San Diego  275487
# 5     Sacramento   524943     16         Fremont         Alameda  230504
# 6    Los Angeles   466742     17   Santa Clarita     Los Angeles  228673
# 7        Alameda   440646     18  San Bernardino  San Bernardino  222101
# 8           Kern   403455     19         Modesto      Stanislaus  218464
# 9         Orange   346824     20   Moreno Valley       Riverside  208634
#
#
#   Unnamed: 8_level_1 Unnamed: 9_level_1
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN
# 5                NaN                NaN
# 6                NaN                NaN
# 7                NaN                NaN
# 8                NaN                NaN
# 9                NaN                NaN
#           0          1                                          2  \
# 0   CA rank  U.S. rank         Metropolitan statistical area[171]
# 1         1          2     Los Angeles-Long Beach-Anaheim, CA MSA
# 2         2         12      San Francisco-Oakland-Hayward, CA MSA
# 3         3         13   Riverside-San Bernardino-Ontario, CA MSA
# 4         4         17                 San Diego-Carlsbad, CA MSA
# 5         5         26  Sacramento–Roseville–Arden-Arcade, CA MSA
# 6         6         35     San Jose-Sunnyvale-Santa Clara, CA MSA
# 7         7         56                             Fresno, CA MSA
# 8         8         62                        Bakersfield, CA MSA
# 9         9         70       Oxnard-Thousand Oaks-Ventura, CA MSA
# 10       10         75                      Stockton-Lodi, CA MSA
#
#                    3                 4        5  \
# 0   2020 census[170]  2010 census[170]   Change
# 1           13200998          12828837   +2.90%
# 2            4749008           4335391   +9.54%
# 3            4599839           4224851   +8.88%
# 4            3298634           3095313   +6.57%
# 5            2397382           2149127  +11.55%
# 6            2000468           1836911   +8.90%
# 7            1008654            930450   +8.40%
# 8             909235            839631   +8.29%
# 9             843843            823318   +2.49%
# 10            779233            685306  +13.71%
#
#                                                     6
# 0                                       Counties[171]
# 1                                 Los Angeles, Orange
# 2   Alameda, Contra Costa, Marin, San Francisco, S...
# 3                           Riverside, San Bernardino
# 4                                           San Diego
# 5                 El Dorado, Placer, Sacramento, Yolo
# 6                             San Benito, Santa Clara
# 7                                              Fresno
# 8                                                Kern
# 9                                             Ventura
# 10                                        San Joaquin
#          0          1                                                  2  \
# 0  CA rank  U.S. rank                     Combined statistical area[170]
# 1        1          2  Los Angeles-Long Beach, CA Combined Statistica...
# 2        2          4  San Jose-San Francisco-Oakland, CA Combined St...
# 3        3         23  Sacramento-Roseville, CA Combined Statistical ...
# 4        4         45        Fresno-Madera, CA Combined Statistical Area
# 5        5        125    Redding-Red Bluff, CA Combined Statistical Area
#
#                   3                 4        5  \
# 0  2020 census[170]  2010 census[170]   Change
# 1          18644680          17877006   +4.29%
# 2           9714023           8923942   +8.85%
# 3           2680831           2414783  +11.02%
# 4           1317395           1234297   +6.73%
# 5            247984            240686   +3.03%
#
#                                                    6
# 0                                      Counties[171]
# 1  Los Angeles, Orange, Riverside, San Bernardino...
# 2  Alameda, Contra Costa, Marin, Merced, Napa, Sa...
# 3  El Dorado, Nevada, Placer, Sacramento, Sutter,...
# 4                              Fresno, Kings, Madera
# 5                                     Shasta, Tehama
#                                                Census  \
# 0                                                1850
# 1                                                1860
# 2                                                1870
# 3                                                1880
# 4                                                1890
# 5                                                1900
# 6                                                1910
# 7                                                1920
# 8                                                1930
# 9                                                1940
# 10                                               1950
# 11                                               1960
# 12                                               1970
# 13                                               1980
# 14                                               1990
# 15                                               2000
# 16                                               2010
# 17                                               2020
# 18                                        2025 (est.)
# 19  Sources: 1790–1990, 2000, 2010, 2020, 2024[172...
#
#                                                  Pop.  \
# 0                                               92597
# 1                                              379994
# 2                                              560247
# 3                                              864694
# 4                                             1213398
# 5                                             1485053
# 6                                             2377549
# 7                                             3426861
# 8                                             5677251
# 9                                             6907387
# 10                                           10586223
# 11                                           15717204
# 12                                           19953134
# 13                                           23667902
# 14                                           29760021
# 15                                           33871648
# 16                                           37253956
# 17                                           39538223
# 18                                           39355309
# 19  Sources: 1790–1990, 2000, 2010, 2020, 2024[172...
#
#                                                  Note  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Sources: 1790–1990, 2000, 2010, 2020, 2024[172...
#
#                                                    %±
# 0                                                   —
# 1                                              310.4%
# 2                                               47.4%
# 3                                               54.3%
# 4                                               40.3%
# 5                                               22.4%
# 6                                               60.1%
# 7                                               44.1%
# 8                                               65.7%
# 9                                               21.7%
# 10                                              53.3%
# 11                                              48.5%
# 12                                              27.0%
# 13                                              18.6%
# 14                                              25.7%
# 15                                              13.8%
# 16                                              10.0%
# 17                                               6.1%
# 18                                              −0.5%
# 19  Sources: 1790–1990, 2000, 2010, 2020, 2024[172...
#            Race and ethnicity[203]  Alone  Alone.1  Total  Total.1
# 0       Hispanic or Latino[note 6]      —      NaN  39.4%      NaN
# 1             White (non-Hispanic)  34.7%      NaN  38.3%      NaN
# 2             Asian (non-Hispanic)  15.1%      NaN  17.0%      NaN
# 3  African American (non-Hispanic)   5.4%      NaN   6.4%      NaN
# 4   Native American (non-Hispanic)   0.4%      NaN   1.3%      NaN
# 5  Pacific Islander (non-Hispanic)   0.3%      NaN   0.7%      NaN
# 6             Other (non-Hispanic)   0.6%      NaN   1.3%      NaN
#                 Racial composition   1950[205]   1960[205] 1970[205]  \
# 0                            White       93.7%         92%       89%
# 1                            Black        4.4%        5.6%        7%
# 2                            Asian        1.7%          2%      2.8%
# 3                  Native American        0.2%        0.2%      0.5%
# 4                 Pacific Islander           —           —         —
# 5                'Some other race'           —        0.1%      0.7%
# 6                Two or more races           —           —         —
# 7    Hispanic or Latino (Any race)   7.2%[209]   9.1%[209]     13.7%
# 8               Non-Hispanic White  86.5%[209]  82.9%[209]     76.3%
# 9               Non-Hispanic Black           —           —         —
# 10              Non-Hispanic Asian           —           —         —
# 11    Non-Hispanic Native American           —           —         —
# 12   Non-Hispanic Pacific Islander           —           —         —
# 13  Non-Hispanic 'some other race'           —           —         —
# 14  Non-Hispanic two or more races           —           —         —
#
#    1980[205] 1990[205] 2000[206] 2010[207] 2020[208]
# 0      76.2%       69%     59.6%     57.6%     41.2%
# 1       7.7%      7.4%      6.7%      6.2%      5.6%
# 2       5.3%      9.6%     10.9%       13%     15.4%
# 3       0.9%      0.8%        1%        1%      1.6%
# 4          —         —      0.4%      0.4%      0.4%
# 7    NaN                 Green            110649       0.48%
# 8  Other                 Other            258490       1.13%
# 9  Total                 Total          22900896        100%
#
#                                                    4
# 0  Party registration by county (October 2022):  ...
# 1  Party registration by county (October 2022):  ...
# 2  Party registration by county (October 2022):  ...
# 3  Party registration by county (October 2022):  ...
# 4  Party registration by county (October 2022):  ...
# 5  Party registration by county (October 2022):  ...
# 6  Party registration by county (October 2022):  ...
# 7  Party registration by county (October 2022):  ...
# 8  Party registration by county (October 2022):  ...
# 9  Party registration by county (October 2022):  ...
#                       0                                                  1  \
# 0  Preceded byWisconsin  List of U.S. states by date of statehood Admit...
#
#                        2
# 0  Succeeded byMinnesota
#          Topics related to California The Golden State  \
# 0    vteState of CaliforniaSacramento (capital)Topi...
# 1                               vteState of California
# 2                                 Sacramento (capital)
# 3                                               Topics
# 4                                              Regions
# ..                                                 ...
# 123                                   Federal district
# 124                                        Territories
# 125                                   Outlying islands
# 126                                     Indian country
# 127                          International concessions
#
#        Topics related to California The Golden State.1
# 0    vteState of CaliforniaSacramento (capital)Topi...
# 1                               vteState of California
# 2                                 Sacramento (capital)
# 3    Culture food languages sports California Dream...
# 4    Antelope Valley Big Sur California Coast Range...
# ..                                                 ...
# 123                                   Washington, D.C.
# 124  American Samoa Guam Northern Mariana Islands P...
# 125  Baker Island Howland Island Jarvis Island John...
# 126  Federally recognized tribe Indian reservation ...
# 127                            Guantanamo Bay Pituffik
#
# [128 rows x 2 columns]
#   vteState of California                           vteState of California.1
# 0   Sacramento (capital)                               Sacramento (capital)
# 1                 Topics  Culture food languages sports California Dream...
# 2                Regions  Antelope Valley Big Sur California Coast Range...
# 3          Metro regions  Fresno–Madera Los Angeles-Long Beach-Anaheim S...
# 4               Counties  Alameda Alpine Amador Butte Calaveras Colusa C...
# 5                  Music  California sound San Francisco sound Bakersfie...
# 6      California portal                                  California portal
#                      vteProtected areas of California  \
# 0   National Park SystemParks Channel Islands Deat...
# 1                                National Park System
# 2   Parks Channel Islands Death Valley Joshua Tree...
# 3                                               Parks
# 4                                           Preserves
# ..                                                ...
# 57  Angelo Coast Range Año Nuevo Island Blue Oak R...
# 58  Private Conservation Land Trusts Agua Hedionda...
# 59                   Private Conservation Land Trusts
# 60  Agua Hedionda Lagoon Arastradero Preserve Arro...
# 61      Heritage registers National Natural Landmarks
#
#                    vteProtected areas of California.1
# 0   National Park SystemParks Channel Islands Deat...
# 1                                National Park System
# 2   Parks Channel Islands Death Valley Joshua Tree...
# 3   Channel Islands Death Valley Joshua Tree Kings...
# 4                                              Mojave
# ..                                                ...
# 57  Angelo Coast Range Año Nuevo Island Blue Oak R...
# 58  Private Conservation Land Trusts Agua Hedionda...
# 59                   Private Conservation Land Trusts
# 60  Agua Hedionda Lagoon Arastradero Preserve Arro...
# 61      Heritage registers National Natural Landmarks
#
# [62 rows x 2 columns]
#                                 National Park System  \
# 0  Parks Channel Islands Death Valley Joshua Tree...
# 1                                              Parks
# 2                                          Preserves
# 3                                          Monuments
# 4                                          Seashores
# 9        Taiwanese indigenous peoples Chamorro people
# 10  Spanish Colonial style by country Colonial Bar...
# 11  Real Columbian exchange Manila galleon Triangu...
# 12  Casta Peninsulares Criollo Indios Mestizo Cast...
# 13  Juan Bautista de Anza Juan Rodríguez Cabrillo ...
#                              0  \
# 0                 Mesoamerican
# 1                    Caribbean
# 2                   California
# 3  Oasisamerica (Southwest US)
# 4                 Aridoamerica
# 5              Southern Plains
# 6       Southeastern Woodlands
# 7                    Filipinos
# 8                       Others
#
#                                                    1
# 0  Aztecs Maya Huastec Mixtec P'urhépecha Totonac...
# 1                        Arawak Ciboney Guanahatabey
# 2  Mission Indians Cahuilla Chumash Cupeño Juaneñ...
# 3  Akimel O'odham Apache Hopi Hualapai Navajo Pue...
# 4  Acaxee Chichimeca Coahuiltecan Cochimí Cocopah...
# 5  Caddo Comanche Lipan Apache Plains Apache Tonk...
# 6  Indigenous people during De Soto's travels Apa...
# 7  Negrito Igorot Mangyan Peoples of Palawan Ati ...
# 8       Taiwanese indigenous peoples Chamorro people
#   vtePolitical divisions of the United States  \
# 0              List of states and territories
# 1                                      States
# 2                            Federal district
# 3                                 Territories
# 4                            Outlying islands
# 5                              Indian country
# 6                   International concessions
#
#        vtePolitical divisions of the United States.1
# 0                     List of states and territories
# 1  Alabama Alaska Arizona Arkansas California Col...
# 2                                   Washington, D.C.
# 3  American Samoa Guam Northern Mariana Islands P...
# 4  Baker Island Howland Island Jarvis Island John...
# 5  Federally recognized tribe Indian reservation ...
# 6                            Guantanamo Bay Pituffik
#   Authority control databases  \
# 0               International
# 1                    National
# 2                  Geographic
# 3                   Academics
# 4                      People
# 5                       Other
#
#                        Authority control databases.1
# 0                            ISNIVIAFGNDFASTWorldCat
# 1  United StatesFrance23BnF data23JapanCzech Repu...
# 2                                   MusicBrainz area
# 3                                              CiNii
# 4                                              Trove
# 5                      IdRefOpen LibraryNARAYale LUX

# %%
# Lets just look at one of these tables
cali_info = CA_data[0].iloc[7:,:] # This just slices off the first few rows
cali_info

# %%
# We can save this information
cali_info.to_csv('my_cali_info.csv')

# %% [markdown]
# ### Read data directly from the clipboard
#
# copy the scientific classification data from: https://en.wikipedia.org/wiki/Cat
#
# then read it into python using the read_clipboard() command.

# %%
df = pd.read_clipboard()
df

# %% [markdown]
# ### Practice Problem 5
#
# Write code that will read in the Jeopardy questions data set using pandas
#
# JEOPARDY_CSV.csv
#
# Then do the following:
#
# 1. Save the questions to a list.
# 2. Save the answers to a list.
# 3. Write code that lets a user practice Jepordy questions
#     - First it should ask if they want to play
#     - If they say yes then it selects a random question and answer pair
#     - Prints out the question
#     - Lets the user type the answer
#     - Checks the answer
#     - If they get it right - congratulate them
#     - If they get it wrong write (append) the question and answer to a file called practice.txt.
#     - Ask them if they want to play again and keep adding to the list of practice questions.

# %%
# Your Code Here

# %% [markdown]
# ### Creative Challenge
#
# There are so many fun data sets out there! Check out https://www.kaggle.com/datasets and see if there is a data set you want to play around with. Can you come up with a fun guessing or matching game for that data set? Or could you learn something about the data using what we know?
